# %% [markdown]
# # Web agent output analysis

# %%
import os
import json

run = '2025-06-16_12-28-10'

nr_success = 0
nr_failed_step_limit = 0
nr_failed_other = 0

for task in os.listdir(f'{run}'):
	file_path = os.path.join(run, task, 'result.json')
	if os.path.exists(file_path):
		with open(file_path, 'r') as f:
			result = json.load(f)
		
			if 'ABORT' in result['final_result_response']:
				if 'step limit' in result['final_result_response']:
					nr_failed_step_limit += 1
				else:
					nr_failed_other += 1
					print(f'Task {task} failed with following reason: {result["final_result_response"]}')
			else:
				nr_success +=1

print(f'Statistics for run {run}:')
print(f'Number of successful tasks: {nr_success}')
print(f'Number of failed tasks: {nr_failed_step_limit + nr_failed_other}')
print(f'Number of failed tasks due to step limit: {nr_failed_step_limit}')
print(f'Number of failed tasks due to other reasons: {nr_failed_other}')
print(f'Accuracy: {nr_success / (nr_success + nr_failed_step_limit + nr_failed_other)}')
print(f'Accuracy (without unknown failures): {nr_success / (nr_success + nr_failed_step_limit)}')
# Out:
# Task 0-1_b7258ee05d75e6c50673a59914db412e failed with following reason: ABORTED: Task aborted. Reason: Cannot access gamestop.com. The task cannot be completed.
# Task 011_123e8c2fc453f55fadd1d0b9aaf94df4 failed with following reason: ABORTED: Task aborted. Reason: Cannot access KBB website.
# Task 014_62f1626ce249c31098854f8b38bdd6cf failed with following reason: ABORTED: Task aborted. Reason: Unable to access gamestop.com
# Task 019_79f0bd7df6e685f30f20025cc6755c0a failed with following reason: ABORTED: Task aborted. Reason: Unable to access gamestop.com
# Task 031_f27c0a7b8b0bb33d37698dff227fc8d7 failed with following reason: ABORTED: Task aborted. Reason: Cannot access KBB.com, access denied.
# Task 042_e7301bb694871429bf2eb36c3a72186c failed with following reason: ABORTED: Task aborted. Reason: Cannot access the page to complete the task.
# Task 045_3c1ffc3f494e423b3c434c79e35da8f3 failed with following reason: ABORTED: Task aborted. Reason: Blocked by network security, cannot proceed with the task
# Task 057_9c97bab9c2abfb90a426cbe9addae8d0 failed with following reason: ABORTED: Task aborted. Reason: Cannot access the page to check order details.
# Task 060_9bb63ad0e38d5691a618932a8b31c05a failed with following reason: ABORTED: captcha
# Task 063_2fc51dd3febd447f0fdcdabca8d944ce failed with following reason: ABORTED: Task aborted. Reason: Cannot proceed past the 'Press & Hold' verification, it keeps reappearing and I cannot perform a 'Press & Hold' action.
# Statistics for run 2025-06-16_12-28-10:
# Number of successful tasks: 12
# Number of failed tasks: 43
# Number of failed tasks due to step limit: 33
# Number of failed tasks due to other reasons: 10
# Accuracy: 0.21818181818181817
# Accuracy (without unknown failures): 0.26666666666666666
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\bened\.conda\envs\i2dl\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
